# %%
import numpy as np
import cora_alad_kdd as cora

import warnings
warnings.filterwarnings('ignore')

# %%
args = dict()
args['dim_h'] = 40         # factor controlling size of hidden layers
args['n_channel'] = 3      # number of channels in the input data (MNIST = 1, greyscale)
args['n_z'] = 32           # number of dimensions in latent space. 
args['sigma'] = 0.5        # variance in n_z
args['lr'] = 0.0001        # learning rate for Adam optimizer
args['epochs'] = 401       # how many epochs to run for
args['batch_size'] = 1000   # batch size for SGD
args['save'] = True       # save weights at each epoch of training if True
args['train'] = True       # train networks if True, else load networks from saved weights

args['scheduler'] = True   # use scheduler for learning rate or not
args['inClass'] = 0        # set which is the class of the inliers

args['subspace_reg']=0.0   # weight for subspace regularization, 0 if not applied
args['wae']=0.1           # WAE-GAN discriminator lambda, 0 if not WAE
args['lipschitz']=0        # Lipschitz penalty weight, 0 if not applied
args['advantage']=True     # Advantage penalty 

args['outratio'] = 0.3     # outlier ration in unlabeled dataset
args['seed'] = 11           # seed for randomness

args['step1set'] = 'x'
args['step2set'] = 'x'
args['paramscloning'] = True

# %%
combinations = [ args.copy() for i in range(2)]

#combinations[0]['subspace_reg']=0.1
#combinations[0]['wae']=0.0
#combinations[0]['advantage']=False
#combinations[0]['paramscloning']=False

#combinations[0]['subspace_reg']=0.1
#combinations[0]['wae']=0.0
#combinations[0]['advantage']=True
#combinations[0]['paramscloning']=True


#combinations[2]['advantage']=False
#combinations[2]['paramscloning']=False

combinations[0]['step1set']='p'
combinations[0]['step2set']='p'
combinations[0]['wae'] = 0.1
combinations[0]['sigma'] = 1.0
combinations[0]['n_z'] = 32
combinations[0]['batch_size'] = 3000

combinations[1]['step1set']='p'
combinations[1]['step2set']='p'
combinations[1]['wae'] = 0.1
combinations[1]['sigma'] = 1.0
combinations[1]['n_z'] = 32
combinations[1]['batch_size'] = 3000
combinations[1]['lr'] = 0.0005


with open('output_tries3_kdd.csv','a+') as fout:
    columns = list(args.keys()) + ["run","epoch","loss","advantageI","precision","recall","F1","AUC","AUPRC","tn", "fp", "fn", "tp"]
    fout.write(";".join(columns) + "\n")
    print(" ".join(columns) + "\n")
    row = 0
    
    for outratio in [0.05,0.1,0.2,0.5]:
        for seed in range(11,15):
            for setting in combinations:
                setting['outratio'] = outratio
                setting['inClass'] = 0
                setting['seed'] = seed
                setting['row'] = row
                values = cora.run(setting)
                for v in values:
                    allv = list(setting.values())  + list(v)
                    strallv = list(map(str,allv))
                    fout.write(";".join(strallv) + '\n')
                print(" ".join(strallv) + '\n')
                row += 1
# Out:
# dim_h n_channel n_z sigma lr epochs batch_size save train scheduler inClass subspace_reg wae lipschitz advantage outratio seed step1set step2set paramscloning run epoch loss advantageI precision recall F1 AUC AUPRC tn fp fn tp
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.05 11 p p True 0 400 0.004438189789652824 -0.00032980478135868907 0.2516629711751663 0.9380165289256198 0.3968531468531468 0.996247749053189 0.9135235415197714 7861 1350 30 454
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.05 11 p p True 1 400 0.00448551494628191 -0.0002047030720859766 0.18472811415349016 0.9896694214876033 0.3113422164445889 0.9871443683486596 0.699037367962776 7097 2114 5 479
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.05 12 p p True 2 400 0.006218473426997662 -0.0007542160456068814 0.21424627277747102 0.7934560327198364 0.3373913043478261 0.9941349411911582 0.8176344987164941 7881 1423 101 388
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.05 12 p p True 3 400 0.006798869464546442 -0.0005115155945532024 0.17196476445806205 0.918200408997955 0.28967741935483876 0.9922583157935458 0.7335051751901638 7142 2162 40 449
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.05 13 p p True 4 400 0.005082626827061176 -7.115205517038703e-05 0.1515025041736227 0.7690677966101694 0.25313807531380755 0.9898830493354904 0.6936819448245379 6935 2033 109 363
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.05 13 p p True 5 400 0.003087396267801523 0.0005239170859567821 0.781786941580756 0.9639830508474576 0.8633776091081594 0.9951562712620391 0.839633715717485 8841 127 17 455
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.05 14 p p True 6 400 0.008331917226314545 -0.0010004574432969093 0.1679454390451833 0.8174273858921162 0.27864214992927866 0.9943786643288021 0.8323068419863846 7211 1952 88 394
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.05 14 p p True 7 400 0.004913784563541412 0.00396862905472517 0.8085867620751341 0.9377593360995851 0.8683957732949087 0.9923768828542356 0.7420888710214681 9056 107 30 452
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.1 11 p p True 8 400 0.00804121233522892 -0.0006080252351239324 0.3185604798400533 0.9865841073271414 0.48161209068010075 0.9962983830394772 0.9619031269677769 6681 2045 13 956
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.1 11 p p True 9 400 0.0046901945024728775 -8.474700734950602e-05 0.32349983238350655 0.9958720330237358 0.4883603238866397 0.9973504800547432 0.9685782067432124 6708 2018 4 965
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.1 12 p p True 10 400 0.0045106010511517525 -0.00016428320668637753 0.31692207368764264 0.992849846782431 0.4804745427582797 0.9938274909936439 0.9053802611596841 6719 2095 7 972
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.1 12 p p True 11 400 0.004069879651069641 0.0011368888663128018 0.8757875787578758 0.9938712972420838 0.9311004784688997 0.9930884633579273 0.880090915162866 8676 138 6 973
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.1 13 p p True 12 400 0.00847666710615158 7.602007826790214e-05 0.32222222222222224 0.9830508474576272 0.48535564853556484 0.9965596970857672 0.9594653659317353 6544 1952 16 928
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.1 13 p p True 13 400 0.008730754256248474 -0.0008456038194708526 0.88124410933082 0.9904661016949152 0.9326683291770573 0.996107215958058 0.9452853116298746 8370 126 9 935
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.1 14 p p True 14 400 0.007674812339246273 0.000576899154111743 0.2830814596387763 0.7966804979253111 0.4177318466140875 0.9954136256937338 0.9412827635630567 6736 1945 196 768
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.1 14 p p True 15 400 0.005104149226099253 -0.0003613013541325927 0.322569198012775 0.9429460580912863 0.48069804336329985 0.9960685830312873 0.9473012413285454 6772 1909 55 909
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.2 11 p p True 16 400 0.0075059253722429276 -0.001176717458292842 0.9278100775193798 0.9876224858174316 0.9567824131901074 0.9967852002848084 0.9854083949553556 7607 149 24 1915
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.2 11 p p True 17 400 0.003980089910328388 -0.0003126702213194221 0.9527093596059113 0.997421351211965 0.9745527840765936 0.9969983145025921 0.9785190295235164 7660 96 5 1934
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.2 12 p p True 18 400 0.0067192306742072105 -0.0004955180338583887 0.514958962139264 0.9933605720122574 0.6782911944202267 0.9964034774945195 0.9740769887324519 6003 1832 13 1945
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.2 12 p p True 19 400 0.004004676826298237 1.436998718418181e-05 0.9475218658892128 0.9959141981613892 0.9711155378486056 0.9942841796423032 0.9433423040589312 7727 108 8 1950
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.2 13 p p True 20 400 0.00792661402374506 -0.000911122013349086 0.9633676092544987 0.7939618644067796 0.870499419279907 0.9948580379425812 0.9757948600391796 7495 57 389 1499
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.2 13 p p True 21 400 0.002989892615005374 0.00015254878962878138 0.9488866396761133 0.993114406779661 0.9704968944099379 0.9967640320893781 0.983127309999368 7451 101 13 1875
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.2 14 p p True 22 400 0.006947193760424852 0.0002651643007993698 0.5184883088635128 0.9885951270088128 0.6802211521312646 0.9944297845683506 0.9584293691793315 5945 1771 22 1907
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.2 14 p p True 23 400 0.004023266956210136 9.008082270156592e-05 0.9412052915237629 0.9958527734577501 0.9677581863979848 0.9925566528291411 0.9391890164606134 7596 120 8 1921
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.5 11 p p True 24 400 0.0065711247734725475 -0.0006198224145919085 0.9897267310458188 0.9936056105610561 0.9916623777663407 0.9970555378557658 0.9963860763303489 4798 50 31 4817
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.5 11 p p True 25 400 0.0033647227101027966 5.222125764703378e-05 0.9879296235679215 0.9960808580858086 0.9919884963023828 0.9978701536614059 0.9969443319375668 4789 59 19 4829
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.5 12 p p True 26 400 0.00577031634747982 -0.00027014079387299716 0.9892210697579825 0.9932611803144783 0.9912370083554106 0.9969215127105404 0.9946216229842578 4844 53 33 4864
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.5 12 p p True 27 400 0.0041793519631028175 3.254282637499273e-05 0.9862292426083434 0.9944864202573004 0.9903406202338587 0.996251137742165 0.9916498817197527 4829 68 27 4870
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.5 13 p p True 28 400 0.010438605211675167 -0.0015623607905581594 0.9905312993161494 0.7978813559322034 0.8838300868340766 0.9925619882935938 0.991258028124545 4684 36 954 3766
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.5 13 p p True 29 400 0.004742852877825499 -4.0608512790640816e-05 0.9879486507728583 0.7989406779661017 0.8834485182148296 0.991885279014651 0.9898293092244732 4674 46 949 3771
#
# 40 3 32 1.0 0.0001 401 3000 True True True 0 0.0 0.1 0 True 0.5 14 p p True 30 400 0.008150681853294373 -0.0004557317588478327 0.987420086615797 0.9927431059506531 0.9900744416873449 0.9959033295131159 0.9922275437138693 4762 61 35 4788
#
# 40 3 32 1.0 0.0005 401 3000 True True True 0 0.0 0.1 0 True 0.5 14 p p True 31 400 0.00703916372731328 -0.0008193776593543589 0.9862281603288797 0.9948165042504665 0.990503715937242 0.9920924122607095 0.9860685959502952 4756 67 25 4798

# %%
row
# Out:
# 32
